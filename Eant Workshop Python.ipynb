# %% [markdown]
#  <img src="https://eant.tech/imagenes/logo.png" width=50% height=80%  >

# %% [markdown]
# **Instructores:**
#
# *  <spand>    <img src="https://logodownload.org/wp-content/uploads/2014/09/twitter-logo-2-1.png" width="20"></spand> Romina Mendez:
# [@r0mymendez](https://twitter.com/r0mymendez)
#
# * <spand>    <img src="https://logodownload.org/wp-content/uploads/2014/09/twitter-logo-2-1.png" width="20"></spand> Karina Bartolome: [@karbartolome](https://twitter.com/karbartolome)
#
#
# * <spand>    <img src="https://logodownload.org/wp-content/uploads/2014/09/twitter-logo-2-1.png" width="20"></spand> Juan Gago : [@Juan_MGago](https://twitter.com/Juan_MGago)

# %% [markdown]
# ## <img src="http://icons.iconarchive.com/icons/cornmanthe3rd/plex/256/Other-python-icon.png" width="40"> Introducción a Data Analytics con Python

# %% [markdown]
# En la primera parte de este workshop vamos a trabajar con los siguientes paquetes:
#
# *   🔹   **[Pandas](https://pandas.pydata.org/):** es un paquete de Python que proporciona estructuras de datos similares a los dataframes de R. Un dataframe es una estructura de datos tabular que se compone de columnas y filas ordenadas
#
# *   🔹   **[Seaborn](https://seaborn.pydata.org/):** es un paquete de visualización de datos de Python basada en matplotlib . Este paquete proporciona una interfaz de alto nivel para dibujar gráficos estadísticos atractivos e informativos.
#
# *   🔹   **[matplotlib.pyplot](https://matplotlib.org/3.1.1/index.html):** es una colección de funciones de estilo.
#
# <br>
#
# -------------
# **{01}** Importar los paquetes:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png" width="30%">

# %% [markdown]
# -------------
# **{01}** Importar el archivo .csv 📁 que se encuentra en el siguiente link
# <br>
# 🔗 https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv
#
# ----------------------
#
#
#
# El **dataset** que vamos a importar se denomina **"tips"** y contiene los datos que un camarero registró sobre cada propina que recibió durante un período de unos meses trabajando en un restaurante.

# %%
'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv'

# %% [markdown]
# -------------
# **{02}** Vamos visualizar los primeras filas del `dataframe`

# %% [markdown]
# -------------
# **{03}** Generar estadisticas descriptivas sobre las variables numericas.

# %% [markdown]
# -------------
# **{04}** Imprimir la cantidad de observaciones y variables que tiene el dataframe

# %% [markdown]
# ## <img src="https://www.metasnake.com/static/img/snslogo.png" width="30%">

# %% [markdown]
# ### 📊 Scatter plot
# -------------
# **{05}** Vamos a generar nuestro primer grafico scatterplot donde:
#
# * x es total_bill
# * y es tip
#
# -------------
# Un **scatter plot**  es un tipo de grafico que utiliza las coordenadas cartesianas para mostrar los valores de dos variables para un conjunto de datos​.

# %% [markdown]
# -------------------
# **{06}** Vamos a modificar el tamaño del plot, por defecto tiene [ancho = 6.4, alto= 4.8], cambiar estos valores por [ancho = 20, alto= 5]

# %% [markdown]
# -------------------
# **{07}** Moificar el color que tiene por defecto de azul y cambiarlo por el color rojo

# %% [markdown]
# -------------------
# **{08}** Asignar un color en base a los valores de la variable denominada "sex"

# %% [markdown]
# -------------------
# **{09}** Asignar un forma diferente a cada point en base a los valores de la variable denominada "smoker"

# %% [markdown]
# -------------------
# **{10}** Modificar el tamaño del point graficado y asignar el valor de 200

# %% [markdown]
# -------------------
# **{11}** Cambiar la opacidad para que se pueda ver más transparente el color y asignar el valor 0.5

# %% [markdown]
# -------------------
# **{12}** Cambiar los colores asignados por defecto, por los colores verde y rojo
# Cambiemos el color asignado para la variable genero

# %% [markdown]
# ----------------
# 🔍 Se pueden buscar paletas de colores en algunas de estas paginas:
#
#
# *   ✏️ **[Adobe Color](https://color.adobe.com/es/explore)**
# *   ✏️ **[Image Color Picke](https://imagecolorpicker.com/)**
# *   ✏️ **[Color Brewer 2](https://colorbrewer2.org/#type=sequential&scheme=BuGn&n=3)**
#
#
# Un color HEX se expresa como una combinación de seis dígitos de números y letras definidos por su combinación de 🔴 rojo, 📗 verde y 🔷 azul (RGB).
# Como por ejemplo:
# <br>
#
# <center>
# <img src="https://img.microsiervos.com/images2018/RGB_ColorHex.jpg" width="70%" height="60%">
# </center>
#
#
#
#
# -------------------

# %% [markdown]
# -------------------
# **{13}** Ahora vamos a modificar los labels:
#
# *   🏷️ Titulo: "Mi primer grafico en Python"
# *   🏷️ Eje x: "Importe del Tickets"
# *   🏷️ Eje y: "Propinas"

# %% [markdown]
# -------------------
# **{14}** Generemos múltiples gráficas donde cada una de ellas pueda mostrar los datos relativos a un valor de la dimensión adicional.
# En nuestro caso generemos un scatter plot para cada uno de los 📅 dias de las semana.
# Agregemos los siguientes labels
# *   🏷️ Titulo: "Grafica en base a la variable size"
# *   🏷️ Eje x: "Importe del Tickets"
# *   🏷️ Eje y: "Propinas"

# %% [markdown]
# -------------------
# **{15}** Generar el mismo grafico pero tener 3 columnas y 2 filas

# %% [markdown]
# -------------------
# **{16}** Generar paneles basados en dos variables, en columnas por la variable "day" y filas por la variable "time"
# Agregemos los siguientes labels
# *   🏷️ Titulo: "Grafica en base a la variable day y time"
# *   🏷️ Eje x: "Importe del Tickets"
# *   🏷️ Eje y: "Propinas"

# %% [markdown]
# -----------------------------
# ###📊 Barplot
# El barplot es una gráfica de barras,donde en el eje x se coloca una variable categórica y las frecuencias en el eje y.
# Para cada factor se genera una barra con alturas proporcionales a la frecuencias
#
# **{01}** Generar un barplot donde en el eje x se encuentre la variable day

# %% [markdown]
# **{02}** Modifiquemos los ejes del grafico realizado en el punto anterior.

# %% [markdown]
# **{03}** Agregamos la variable "sex"

# %% [markdown]
# -----------------------------
# ###📊 Distplot
# El distplot nos sirve para crear un histograma de la distribución de una variable numérica
#
# **{01}** Generamos una histograma para la variable total_bill

# %% [markdown]
# **{02}** Podemos comparar distribuciones de total_bill y tip

# %% [markdown]
# -----------------------------
# ###📊 Boxplot
# El boxplot es un gráfico para visualizar la distribución de una variable numérica  usando cuantiles.
#
# **{01}** Generemos nuestro boxplot donde en el x este la variable day y en el eje y total_bill, asignar los colores siguientes:
#
#
# *   #8FB6FF
# *   #76E8A4

# %% [markdown]
# -----------------------------
# ###📊 Violinplot
# **{01}** Ahora vamos un punto para cada observación, donde la variable x es "day" y la variable y es "total_bill", asignar los mismos colores utilizados en el boxplot.

# %% [markdown]
# # <img src="https://www.kindpng.com/picc/m/126-1264499_plotly-icon-hd-png-download.png" width="30%">

# %% [markdown]
# **Plotly** proporciona herramientas de gráficos, análisis y estadísticas, así como paquetes de código abierto con implementación de gráficos interactivos para Python , R , MATLAB , Perl , Julia, Arduino y REST .
# Para conocer más de la implementación de Ploty en Python: https://plotly.com/python/
#
# <br>
#
# **{01}** Impotar el paquete plotly.express

# %%
import plotly.express as px

# %% [markdown]
# -----------------------------
# ### 📊 Scatterplot
#
# **{01}** Generar un scatter plot donde el eje x es "total_bill" y el eje y es "tip"

# %% [markdown]
# **{02}** Asignar colores en base a la variable "day"

# %% [markdown]
# **{03}** Modificar el tamaño de los points en base a la variable "size"

# %% [markdown]
# **{04}** Generar paneles en base a la variable "sex"

# %% [markdown]
# **{05}** Generar un scatter plot en 3d donde la variable **"x"** es "total_bill", la variable **"y"** es "tip" y la variable **"z"** es "size

# %% [markdown]
# **{06}** Modificar el grafico anterior y asignar un color en base a la variable "day"

# %% [markdown]
# -----------------------------
# ###📊 Box
#
# **{01}** Generar un box plot donde el eje x es "day" y el eje y es "total_bill"

# %% [markdown]
# -----------------------------
# ###📊 Violin Plot
#
# **{01}** Generar un box plot donde el eje x es "smoker" y el eje y es "total_bill"

# %% [markdown]
# -----------------------------
# ###📊 Pie Plot

# %% [markdown]
# # 📢 Datos de Contacto:
#
# * 🔗 [eant.tech](https://eant.tech/)
# * <img src="https://logodownload.org/wp-content/uploads/2014/09/twitter-logo-2-1.png" width="20">  [@eanttech](https://twitter.com/eanttech)
# * <img src="https://logodownload.org/wp-content/uploads/2017/04/instagram-logo-9.png" width="20">  [@eanttech](https://www.instagram.com/eanttech/)
